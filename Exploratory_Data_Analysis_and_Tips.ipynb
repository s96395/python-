# %% [markdown]
# **𝐸𝑥𝑝𝑙𝑜𝑟𝑎𝑡𝑜𝑟𝑦𝐷𝑎𝑡𝑎𝐴𝑛𝑎𝑙𝑦𝑠𝑖𝑠𝑎𝑛𝑑𝑇𝑖𝑝𝑠**
#
# 探索性資料分析(Exploratory Data Anlysis, 簡稱EDA)是機器學習/資料科學專案中非常重要的步驟，它是透過描述性統計以及資料視覺化的方式讓我們快速瞭解資料在各個面向的狀況，以便我們找到關鍵的因素往下進行後續分析。
#
# 雖然探索性資料分析非常重要，在一些絢麗的機器學習模型與技巧下卻相形失色，另外探索性資料分析也需要結合分析人員對資料的了解，所以在實務上這個步驟常被忽略或輕視。不過在使用得當的狀況下，在探索性資料分析的階段就可以找到資料中特別的資訊與重要的特徵，甚至能找出商業價值。
#
# ![The-Data-Science-Process-41.png](data:image/png;base64,...)

# %%
# 載入套件
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# **統計量的使用提醒**
#
# 平均數、中位數、眾數的選擇
#
#
# *   我們知道平均數、中位數、跟眾數都可以代表一群資料的分布集中狀況，但是這三個數值的選擇上又應該考量甚麼因素呢？
#
# ![central_tendency.PNG](data:image/png;base64,...)
#
# * 偏態與集中趨勢指標的關聯
# ![skewness_central.PNG](data:image/png;base64,...)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e98d3f6f-4d4e-4ae1-95df-86997ebd5697" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e98d3f6f-4d4e-4ae1-95df-86997ebd5697">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving titanc_train.csv to titanc_train.csv

# %%
dat = pd.read_csv('titanc_train.csv')

# %%
dat['Fare'].hist()

# %%
fare_mean = dat['Fare'].mean()
print(fare_mean)
# Out:
# 32.2042079685746

# %%
less_than_mean = np.mean(dat['Fare'] < fare_mean)
print(less_than_mean)
# Out:
# 0.7631874298540965

# %%
fare_median = dat['Fare'].median()
print(fare_median)
# Out:
# 14.4542

# %% [markdown]
# **資料視覺化小技巧**
#
# 直方圖與箱型圖的選擇
#
# ![histogram_.PNG](data:image/png;base64,...)
#
# ![boxplot_.PNG](data:image/png;base64,...)

# %% [markdown]
# 直方圖與箱型圖比較
#
# ![hist_boxplot_comparison.PNG](data:image/png;base64,...)

# %% [markdown]
# **圓餅圖的錯誤使用範例**
#
# 多類別的圓餅圖
#
# ![pieplot_1.PNG](data:image/png;base64,...)

# %% [markdown]
# 圓餅圖的比較
#
# ![pieplot_2.PNG](data:image/png;base64,...)

# %% [markdown]
# 3D造成的視覺效果
#
# ![pieplot_3.PNG](data:image/png;base64,...)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4a7c5d8a-2a40-4f1c-bd9c-255021190cb0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4a7c5d8a-2a40-4f1c-bd9c-255021190cb0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving boston_house.csv to boston_house.csv

# %%
dat = pd.read_csv('boston_house.csv')
dat.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX  ...    TAX  PTRATIO       B  LSTAT  target
# 0  0.00632  18.0   2.31   0.0  0.538  ...  296.0     15.3  396.90   4.98    24.0
# 1  0.02731   0.0   7.07   0.0  0.469  ...  242.0     17.8  396.90   9.14    21.6
# 2  0.02729   0.0   7.07   0.0  0.469  ...  242.0     17.8  392.83   4.03    34.7
# 3  0.03237   0.0   2.18   0.0  0.458  ...  222.0     18.7  394.63   2.94    33.4
# 4  0.06905   0.0   2.18   0.0  0.458  ...  222.0     18.7  396.90   5.33    36.2
#
# [5 rows x 14 columns]

# %%
plt.scatter(dat['CHAS'], dat['NOX'])
plt.xlabel('CHAS')
plt.ylabel('NOX')
plt.show()

# %%
# 較好的做法是使用群組的箱型圖做比較
dat.boxplot('NOX', by='CHAS')
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
plt.scatter(dat['TAX'], dat['RAD'])
plt.xlabel('TAX')
plt.ylabel('RAD')
plt.show()

# %%
plt.hist(dat['TAX'], bins=20)
plt.show()

# %%
# 調整透明度參數使資料分布較明顯

plt.scatter(dat['TAX'], dat['RAD'], alpha=0.1)
plt.xlabel('TAX')
plt.ylabel('RAD')
plt.show()

# %% [markdown]
# 在資料的視覺化上，其實還有很多需要注意的地方，未來大家在進行資料探索時請務必記得多方面交叉比較資訊是否一致。 另外，雖然很多圖形非常的絢麗美觀，但在資訊的呈現上其實基本的統計圖表並不輸給它們，在決定選用何種圖形前可以先思考一下目前想呈現的資訊為何，才能選擇到適合的圖形唷。
